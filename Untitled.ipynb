# %%
# clone repository for deepsort with yolov4
#!git clone https://github.com/theAIGuysCode/yolov4-deepsort

# %%
# step into the yolov4-deepsort folder
# %cd yolov4-deepsort/
# Out:
# D:\deepSORT\deeSORT_youtubedemo\yolov4-deepsort

# %%
# Convert darknet weights to tensorflow model

# !python save_model.py --model yolov4
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 416, 416, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 416, 416, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Softplus (TensorFlo [(None, 416, 416, 32 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# run DeepSort with YOLOv4 Object Detections as backbone (enable --info flag to see info about tracked objects)
# !python object_tracker.py --video ./data/video/demotraffic.mp4 --output ./outputs/trafficdemooutput.avi --model yolov4 --dont_show --info
# Out:
# Frame #:  1
# FPS: 0.27
# Frame #:  2
# FPS: 22.24
# Frame #:  3
# Tracker ID: 1, Class: speed limit,  BBox Coords (xmin, ymin, xmax, ymax): (242, 91, 323, 185)
# Tracker ID: 2, Class: yield,  BBox Coords (xmin, ymin, xmax, ymax): (238, 225, 367, 399)
# FPS: 21.74
# Frame #:  4
# Tracker ID: 1, Class: speed limit,  BBox Coords (xmin, ymin, xmax, ymax): (241, 88, 322, 181)
# Tracker ID: 2, Class: yield,  BBox Coords (xmin, ymin, xmax, ymax): (235, 221, 370, 403)
# FPS: 23.27
# Frame #:  5
# Tracker ID: 1, Class: speed limit,  BBox Coords (xmin, ymin, xmax, ymax): (236, 79, 323, 181)
# FPS: 22.72
# Frame #:  6
# Tracker ID: 1, Class: speed limit,  BBox Coords (xmin, ymin, xmax, ymax): (237, 79, 318, 175)
# FPS: 23.28
# Frame #:  7
# Tracker ID: 1, Class: speed limit,  BBox Coords (xmin, ymin, xmax, ymax): (239, 79, 314, 167)
# FPS: 21.32
# Frame #:  8
# Tracker ID: 1, Class: speed limit,  BBox Coords (xmin, ymin, xmax, ymax): (237, 73, 313, 164)
# FPS: 21.74
# Frame #:  9
# ...

# %%
# compressed the voutput video because jupyter notebook not displaying biggere size video. 
from ipywidgets import Video
#Video.from_file("outputs/demotrafficoutput1.mp4", width=1000, height=400)
